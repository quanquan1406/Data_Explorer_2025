# %%
import pandas as pd

# Đọc dữ liệu từ file CSV
file_path = "./DATA EXPLORER CONTEST/Data - 12ndMar/4.2.3 (TARGET) (live & his) FPT_detail_transactions_processed.csv"
df_FPT = pd.read_csv(file_path)

# Xem thông tin tổng quan
print("Kích thước dữ liệu:", df_FPT.shape)
print("\nCác cột dữ liệu:\n", df_FPT.dtypes)
print("\nDữ liệu bị thiếu:\n", df_FPT.isnull().sum())
print("\n5 dòng đầu tiên của dữ liệu:")
print(df_FPT.head())
# Out:
# Kích thước dữ liệu: (240, 10)
#
# Các cột dữ liệu:
#  StockID            object
# Date               object
# Total Volume       object
# Total Value        object
# Market Cap         object
# Closing Price      object
# Price Change       object
# Price Change %    float64
# Matched Volume     object
# Matched Value      object
# dtype: object
#
# Dữ liệu bị thiếu:
#  StockID           0
# Date              0
# Total Volume      0
# Total Value       0
# Market Cap        0
# Closing Price     0
# Price Change      0
# Price Change %    0
# Matched Volume    0
# Matched Value     0
# dtype: int64
#
# 5 dòng đầu tiên của dữ liệu:
#   StockID        Date Total Volume Total Value   Market Cap Closing Price  \
# 0     FPT  12/03/2025    6,365,000     870,067  199,918,302       135,900
# 1     FPT  11/03/2025    6,164,400     849,430  202,272,013       137,500
# 2     FPT  10/03/2025    5,681,900     796,168  204,919,937       139,300
# ...

# %%
# Chuyển đổi cột 'Date' sang datetime
df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y")

# Hàm chuyển đổi số có dấu ','
def convert_numeric(column):
    return df[column].astype(str).str.replace(",", "").astype(float)

# Chuyển đổi các cột số sang dạng float
num_cols = ["Total Volume", "Total Value", "Market Cap", "Closing Price", 
            "Price Change", "Matched Volume", "Matched Value"]
for col in num_cols:
    df[col] = convert_numeric(col)

# Kiểm tra lại kiểu dữ liệu
print(df.dtypes)
print(df.head())
# Out:
# StockID                   object
# Date              datetime64[ns]
# Total Volume             float64
# Total Value              float64
# Market Cap               float64
# Closing Price            float64
# Price Change             float64
# Price Change %           float64
# Matched Volume           float64
# Matched Value            float64
# dtype: object
#   StockID       Date  Total Volume  Total Value   Market Cap  Closing Price  \
# 0     FPT 2025-03-12     6365000.0     870067.0  199918302.0       135900.0
# 1     FPT 2025-03-11     6164400.0     849430.0  202272013.0       137500.0
# 2     FPT 2025-03-10     5681900.0     796168.0  204919937.0       139300.0
# 3     FPT 2025-03-07     3436000.0     486821.0  208009182.0       141400.0
# 4     FPT 2025-03-06     6511400.0     921080.0  208303396.0       141600.0
#
#    Price Change  Price Change %  Matched Volume  Matched Value
# 0       -1600.0           -1.16       6185000.0       844877.0
# ...
