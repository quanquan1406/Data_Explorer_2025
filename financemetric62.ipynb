# %%
import pandas as pd
import numpy as np

# %%
file_path = "DATA EXPLORER CONTEST/Data - 12ndMar/6.2 (his) financialreport_metrics_FPT_CMG_processed.csv"

dataframe = pd.read_csv(file_path)

dataframe.head()
# Out:
#                              Indicator StockID Q1_2023 Q1_2024 Q2_2023  \
# 0                            Beta\nLần     CMG    1.02    0.93    1.04
# 1                            Beta\nLần     FPT    0.78    0.76    0.74
# 2  Chi phí bán hàng/Doanh thu thuần\n%     CMG    5.61    6.70    6.34
# 3  Chi phí bán hàng/Doanh thu thuần\n%     FPT    9.43    9.71    9.92
# 4   Chi phí lãi vay/Doanh thu thuần\n%     CMG    1.16    1.02    1.27
#
#   Q2_2024 Q3_2023 Q3_2024 Q4_2023 Q4_2024
# 0    1.18    0.94    1.19    1.01     NaN
# 1    0.80    0.75    0.81    0.77    0.96
# 2    6.01    5.75    5.82    8.53     NaN
# 3   10.42   10.42    9.83    8.96    9.57
# 4    0.93    1.17    1.05    0.97     NaN

# %%
# Lọc theo điều kiện Indicator và StockID
filtered_df = dataframe[
    (dataframe['Indicator'].str.contains("EPS", regex=True)) &
    (dataframe['StockID'] == 'FPT')
]
filtered_df
# Out:
#                                             Indicator StockID Q1_2023 Q1_2024  \
# 41  Thu nhập trên mỗi cổ phần của 4 quý gần nhất (...     FPT   5,258   5,541
#
#    Q2_2023 Q2_2024 Q3_2023 Q3_2024 Q4_2023 Q4_2024
# 41   5,289   5,618   5,362   5,652   5,476   5,697

# %%
# Tạo một danh sách các ngày từ 26/3/2024 đến 12/3/2025
date_range = pd.date_range(start='2024-03-26', end='2025-03-12')

# Tạo dataframe chỉ chứa cột ngày tháng và khởi tạo cột 'Lợi nhuận' với giá trị NaN
bang_EPS = pd.DataFrame({'Date': date_range})
bang_EPS['EPS'] = np.nan

# Lặp qua các hàng trong filtered_df
for item in filtered_df.columns:
    if item == 'Q4_2023':  # Kiểm tra nếu cột là 'Q4_2023'
        for i, date in enumerate(bang_EPS['Date']):
            # Kiểm tra điều kiện ngày tháng
            if 1 <= date.month <= 3 and 1 <= date.day <= 31 and date.year == 2024:
                bang_EPS.loc[i, 'EPS'] = filtered_df[item].values[0]
    if item == 'Q1_2024':  # Kiểm tra nếu cột là 'Q1_2024'
        for i, date in enumerate(bang_EPS['Date']):
            # Kiểm tra điều kiện ngày tháng
            if 4 <= date.month <= 6 and 1 <= date.day <= 31 and date.year == 2024:
                bang_EPS.loc[i, 'EPS'] = filtered_df[item].values[0]  # Gán giá trị vào cột 'Lợi nhuận'
    elif item == 'Q2_2024':
        for i, date in enumerate(bang_EPS['Date']):
            # Kiểm tra điều kiện ngày tháng
            if 7 <= date.month <= 9 and 1 <= date.day <= 31 and date.year == 2024:
                bang_EPS.loc[i, 'EPS'] = filtered_df[item].values[0]
    elif item == 'Q3_2024':
        for i, date in enumerate(bang_EPS['Date']):
            # Kiểm tra điều kiện ngày tháng
            if 10 <= date.month <= 12 and 1 <= date.day <= 31 and date.year == 2024:
                bang_EPS.loc[i, 'EPS'] = filtered_df[item].values[0]
    elif item == 'Q4_2024':
        for i, date in enumerate(bang_EPS['Date']):
            # Kiểm tra điều kiện ngày tháng
            if 1 <= date.month <= 3 and 1 <= date.day <= 31 and date.year == 2025:
                bang_EPS.loc[i, 'EPS'] = filtered_df[item].values[0]

# Kiểm tra kết quả  
bang_EPS

# Xuất kết quả ra file CSV
bang_EPS.to_csv('EPS_FPT.csv', index=False)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15376\2642038252.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5,541' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   bang_EPS.loc[i, 'EPS'] = filtered_df[item].values[0]  # Gán giá trị vào cột 'Lợi nhuận'
